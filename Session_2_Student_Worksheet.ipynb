# %% [markdown]
# # 📊 Session 2 — Student Worksheet (Pandas + Plotly)
# Work in small groups. Find a CSV dataset on GitHub, load it in Colab, and adapt commands from the workbook.
# Be ready to walk through your code at the end.

# %% [markdown]
# ## Part 1 — Find a Dataset (GitHub)

# %%
#csv_url = "https://tradingeconomics.com/matrix"
#csv_url
# Out:
# 'https://github.com/phant0mZY/Indian-Macroeconomic-Indicators-Dataset/blob/main/finance.csv'

# %%
#data = 'https://drive.google.com/drive/my-drive'

# %% [markdown]
# ## Part 2 — Load & Inspect

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = "/content/drive/MyDrive/macro_indicators.csv"

# %%
import pandas as pd

# Read CSV
df = pd.read_csv(data)
print(df.head())
# Out:
#          Country    GDP  GDP Growth  Interest Rate  Inflation Rate  \
# 0  United States  29185         3.8           4.25             2.9
# 1          China  18744         1.1           3.00            -0.4
# 2      Euro Area  16406         0.1           2.15             2.0
# 3        Germany   4660        -0.3           2.15             2.2
# 4          Japan   4026         0.5           0.50             2.7
#
#    Jobless Rate  Gov. Budget  Debt/GDP  Current Account  Population
# 0           4.3         -6.4     124.3             -3.9      341.15
# 1           5.3         -6.5      88.3              2.2     1408.00
# 2           6.2         -3.1      87.4              2.6      351.38
# 3           6.3         -2.8      62.5              5.7       83.58
# 4           2.3         -2.3     236.7              4.7      120.65

# %% [markdown]
# ## Part 3 — Explore & Clean

# %%
df_15 = df.sort_values('GDP', ascending=False).head(15)
df_15
# Out:
#            Country    GDP  GDP Growth  Interest Rate  Inflation Rate  \
# 0    United States  29185         3.8           4.25            2.90
# 1            China  18744         1.1           3.00           -0.40
# 2        Euro Area  16406         0.1           2.15            2.00
# 3          Germany   4660        -0.3           2.15            2.20
# 4            Japan   4026         0.5           0.50            2.70
# 5            India   3913         1.7           5.50            2.07
# 6   United Kingdom   3644         0.3           4.00            3.80
# 7           France   3162         0.3           2.15            0.90
# 8            Italy   2373        -0.1           2.15            1.60
# 9           Canada   2241        -0.4           2.50            1.90
# 10          Brazil   2179         0.4          15.00            5.13
# 11          Russia   2174        -0.8          17.00            8.10
# 12          Mexico   1853         0.6           7.50            3.57
# 13       Australia   1752         0.6           3.60            2.10
# 14           Spain   1723         0.8           2.15            2.70
#
#     Jobless Rate  Gov. Budget  Debt/GDP  Current Account  Population
# 0           4.30         -6.4    124.30            -3.90      341.15
# 1           5.30         -6.5     88.30             2.20     1408.00
# 2           6.20         -3.1     87.40             2.60      351.38
# 3           6.30         -2.8     62.50             5.70       83.58
# 4           2.30         -2.3    236.70             4.70      120.65
# 5           5.10         -4.8     81.92            -0.60     1398.60
# 6           4.70         -4.8     95.90            -2.70       69.23
# 7           7.50         -5.8    113.00             0.40       68.44
# 8           6.00         -3.4    135.30             1.10       58.93
# 9           7.10         -2.1    110.80            -1.00       41.53
# 10          5.60         -8.5     76.50            -2.55      212.58
# 11          2.20         -1.7     16.40             2.90      146.20
# 12          2.80         -5.7     49.70            -0.80      130.86
# 13          4.20          0.6     43.80            -2.00       27.40
# 14         10.29         -3.2    101.80             3.10       49.08

# %% [markdown]
# ## Part 4 — Summarization

# %%
category_col = 'REPLACE_ME'
numeric_col = 'REPLACE_ME'

by_cat = df.groupby(category_col)[numeric_col].sum().sort_values(ascending=False)
by_cat.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2512979515.py in <cell line: 0>()
#       2 numeric_col = 'REPLACE_ME'
#       3
# ----> 4 by_cat = df.groupby(category_col)[numeric_col].sum().sort_values(ascending=False)
#       5 by_cat.head(10)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041                 in_axis, level, gpr = False, gpr, None
#    1042             else:
# -> 1043                 raise KeyError(gpr)
#    1044         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045             # Add key to exclusions
#
# KeyError: 'REPLACE_ME'

# %% [markdown]
# ## Part 5 — Visualization (Pandas + Plotly)

# %%
import plotly.express as px

bar_df_15 = df_15.reset_index()
fig = px.bar(bar_df_15, x='Country', y='GDP', title=f'Top 15 {'GDP'} (interactive)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="86a50460-1f22-4161-8b44-a4ed51a7f9e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86a50460-1f22-4161-8b44-a4ed51a7f9e9")) {                    Plotly.newPlot(                        "86a50460-1f22-4161-8b44-a4ed51a7f9e9",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003eGDP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["United States","China","Euro Area","Germany","Japan","India","United Kingdom","France","Italy","Canada","Brazil","Russia","Mexico","Australia","Spain"],"xaxis":"x","y":[29185,18744,16406,4660,4026,3913,3644,3162,2373,2241,2179,2174,1853,1752,1723],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color": ...

# %%
import plotly.express as px

scatter_df = df.reset_index()
scatter_df['Size'] = scatter_df['Country'].apply(lambda x: 40 if x == 'Brazil' else 3)
fig = px.scatter(scatter_df,
                 x='Interest Rate',
                 y='Inflation Rate',
                 title = 'Countries',
                 color = 'Country',
                 size = 'Size')

fig.update_xaxes(range=[0, 20])   # x-axis from 0 to 20
fig.update_yaxes(range=[0, 20])  # y-axis from -5 to 15

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="21439323-dd4e-401c-a483-dd443cc9fa2b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21439323-dd4e-401c-a483-dd443cc9fa2b")) {                    Plotly.newPlot(                        "21439323-dd4e-401c-a483-dd443cc9fa2b",                        [{"hovertemplate":"Country=United States\u003cbr\u003eInterest Rate=%{x}\u003cbr\u003eInflation Rate=%{y}\u003cbr\u003eSize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United States","marker":{"color":"#636efa","size":[3],"sizemode":"area","sizeref":0.1,"symbol":"circle"},"mode":"markers","name":"United States","orientation":"v","showlegend":true,"x":[4.25],"xaxis":"x","y":[2.9],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=China\u003cbr\u003eInterest Rate=%{x}\u003cbr\u003eInflation Rate=%{y}\u003cbr\u003eSize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"China","marker":{"color":"#EF553B","size":[3],"sizemode":"area","sizeref":0.1,"symbol":"circle"},"mode":"markers","name":"China","orientation":"v","showlegend":true,"x":[3.0],"xaxis":"x","y":[-0.4],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Euro Area\u003cbr\u003eInterest Rate=%{x}\u003cbr\u003eInflation Rate=%{y}\u003cbr\u003eSize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Euro Area","marker":{"color":"#00cc96","size":[3],"sizemode":"area","sizeref":0.1,"symbol":"circle"},"mode":"markers","name":"Euro Area","orientation":"v","showlegend":true,"x":[2.15],"xaxis":"x","y":[2.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Germany\u003cbr\u003eInterest Rate=%{x}\u003cbr\u003eInflation Rate=%{y}\u003cbr\u003eSize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Germany","marker":{"color":"#ab63fa","size":[3],"sizemode":"area","sizeref":0.1,"symbol":"circle"},"mode":"markers","name":"Germany","orientation":"v","showlegend":true,"x":[2.15],"xaxis":"x","y":[2.2],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Japan\u003cbr\u003eInterest Rate=%{x}\u003cbr\u003eInflation Rate=%{y}\u003cbr\u003eSize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Japan","marker":{"color":"#FFA15A","size":[3],"sizemode":"area","sizeref":0.1,"symbol":"circle"},"mode":"markers","name":"Japan","orientation":"v","showlegend":true,"x":[0.5],"xaxis":"x","y":[2.7],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=India\u003cbr\u003eInterest Rate=%{x}\u003cbr\u003eInflation Rate=%{y}\u003cbr\u003eSize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"India","marker":{"color":"#19d3f3","size":[3],"sizemode":"area","sizeref":0.1,"symbol":"circle"},"mode":"markers","name":"India","orientation":"v","showlegend":true,"x":[5.5],"xaxis":"x","y":[2.07],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=United Kingdom\u003cbr\u003eInterest Rate=%{x}\u003cbr\u003eInflation Rate=%{y}\u003cbr\u003eSize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United Kingdom","marker":{"color":"#FF6692","size":[3],"sizemode":"area","sizeref":0.1,"symbol":"circle"},"mode":"markers","name":"United Kingdom","orientation":"v","showlegend":true,"x":[4.0],"xaxis":"x","y":[3.8],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=France\u003cbr\u003eInterest Rate=%{x}\u003cbr\u003eInflation Rate=%{y}\u003cbr\u003eSize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#B6E880","size":[3],"sizemode":"area","sizeref":0.1,"symbol":"circle"},"mode":"markers","name":"France","orientation":"v","showlegend":true,"x":[2.15],"xaxis":"x","y":[0.9],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Italy\u003cbr\u003eInterest  ...

# %%
scatter_df = df.reset_index().sort_values('Debt/GDP', ascending = False)
scatter_df['Size'] = scatter_df['Country'].apply(lambda x: 40 if x == 'Brazil' else 3)
fig = px.scatter(scatter_df,
                 x='Interest Rate',
                 y='Debt/GDP',
                 title = 'Countries',
                 color = 'Country',
                 size = 'Size')

fig.update_xaxes(range=[0, 20])   # x-axis from 0 to 20
#fig.update_yaxes(range=[0, 20])  # y-axis from -5 to 15

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="018681f3-8f34-4b96-8879-37f5f566b035" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("018681f3-8f34-4b96-8879-37f5f566b035")) {                    Plotly.newPlot(                        "018681f3-8f34-4b96-8879-37f5f566b035",                        [{"hovertemplate":"Country=Sudan\u003cbr\u003eInterest Rate=%{x}\u003cbr\u003eDebt\u002fGDP=%{y}\u003cbr\u003eSize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sudan","marker":{"color":"#636efa","size":[3],"sizemode":"area","sizeref":0.1,"symbol":"circle"},"mode":"markers","name":"Sudan","orientation":"v","showlegend":true,"x":[28.3],"xaxis":"x","y":[272.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Japan\u003cbr\u003eInterest Rate=%{x}\u003cbr\u003eDebt\u002fGDP=%{y}\u003cbr\u003eSize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Japan","marker":{"color":"#EF553B","size":[3],"sizemode":"area","sizeref":0.1,"symbol":"circle"},"mode":"markers","name":"Japan","orientation":"v","showlegend":true,"x":[0.5],"xaxis":"x","y":[236.7],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Singapore\u003cbr\u003eInterest Rate=%{x}\u003cbr\u003eDebt\u002fGDP=%{y}\u003cbr\u003eSize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Singapore","marker":{"color":"#00cc96","size":[3],"sizemode":"area","sizeref":0.1,"symbol":"circle"},"mode":"markers","name":"Singapore","orientation":"v","showlegend":true,"x":[1.32],"xaxis":"x","y":[173.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Venezuela\u003cbr\u003eInterest Rate=%{x}\u003cbr\u003eDebt\u002fGDP=%{y}\u003cbr\u003eSize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Venezuela","marker":{"color":"#ab63fa","size":[3],"sizemode":"area","sizeref":0.1,"symbol":"circle"},"mode":"markers","name":"Venezuela","orientation":"v","showlegend":true,"x":[59.06],"xaxis":"x","y":[164.3],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Lebanon\u003cbr\u003eInterest Rate=%{x}\u003cbr\u003eDebt\u002fGDP=%{y}\u003cbr\u003eSize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Lebanon","marker":{"color":"#FFA15A","size":[3],"sizemode":"area","sizeref":0.1,"symbol":"circle"},"mode":"markers","name":"Lebanon","orientation":"v","showlegend":true,"x":[20.0],"xaxis":"x","y":[164.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Eritrea\u003cbr\u003eInterest Rate=%{x}\u003cbr\u003eDebt\u002fGDP=%{y}\u003cbr\u003eSize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Eritrea","marker":{"color":"#19d3f3","size":[3],"sizemode":"area","sizeref":0.1,"symbol":"circle"},"mode":"markers","name":"Eritrea","orientation":"v","showlegend":true,"x":[null],"xaxis":"x","y":[164.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Greece\u003cbr\u003eInterest Rate=%{x}\u003cbr\u003eDebt\u002fGDP=%{y}\u003cbr\u003eSize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Greece","marker":{"color":"#FF6692","size":[3],"sizemode":"area","sizeref":0.1,"symbol":"circle"},"mode":"markers","name":"Greece","orientation":"v","showlegend":true,"x":[2.15],"xaxis":"x","y":[153.6],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Italy\u003cbr\u003eInterest Rate=%{x}\u003cbr\u003eDebt\u002fGDP=%{y}\u003cbr\u003eSize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Italy","marker":{"color":"#B6E880","size":[3],"sizemode":"area","sizeref":0.1,"symbol":"circle"},"mode":"markers","name":"Italy","orientation":"v","showlegend":true,"x":[2.15],"xaxis":"x","y":[135.3],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Bahrain\u003cbr\u003eInterest Rate=%{x}\u003cbr\u00 ...

# %%
import plotly.express as px

brics = ['Brazil', 'Russia', 'India', 'China', 'South Africa']

scatter_df = df.reset_index().sort_values('Debt/GDP', ascending=False)
scatter_df['Group'] = scatter_df['Country'].apply(lambda x: x if x in brics else 'Other')

# Make Brazil larger
scatter_df['Size'] = scatter_df['Country'].apply(lambda x: 200 if x == 'Brazil' else 30)

fig = px.scatter(
    scatter_df,
    x='Interest Rate',
    y='Debt/GDP',
    title='Countries',
    color='Group',
    size='Size',
    color_discrete_map={
        'Brazil': 'green',
        'Russia': 'red',
        'India': 'orange',
        'China': 'blue',
        'South Africa': 'purple',
        'Other': 'lightgray'
    },
    hover_name='Country'
)

fig.update_xaxes(range=[0, 20])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="460230cc-3233-4edc-bad5-7932a4d0b9d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("460230cc-3233-4edc-bad5-7932a4d0b9d8")) {                    Plotly.newPlot(                        "460230cc-3233-4edc-bad5-7932a4d0b9d8",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eGroup=Other\u003cbr\u003eInterest Rate=%{x}\u003cbr\u003eDebt\u002fGDP=%{y}\u003cbr\u003eSize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Sudan","Japan","Singapore","Venezuela","Lebanon","Eritrea","Greece","Italy","Bahrain","United States","Cuba","France","Canada","Cape Verde","Bhutan","Belgium","Sao Tome and Principe","Spain","Sri Lanka","United Kingdom","Republic of the Congo","Bolivia","Portugal","Jordan","Ukraine","Malawi","Euro Area","Suriname","Zimbabwe","Argentina","Libya","Egypt","Finland","Mauritius","Austria","Bahamas","Guinea Bissau","Pakistan","Tunisia","Fiji","Mozambique","Costa Rica","Hungary","Gabon","Gambia","Yemen","Ghana","Malaysia","Uruguay","Morocco","Zambia","Israel","Togo","Laos","Jamaica","Rwanda","Slovenia","Kenya","Namibia","Cyprus","Thailand","Germany","Maldives","Colombia","Myanmar","El Salvador","Seychelles","Central African Republic","Philippines","Montenegro","Lesotho","Iceland","Slovakia","Trinidad and Tobago","Angola","Croatia","Dominican Republic","Panama","Senegal","Poland","Norway","Liberia","Romania","Albania","Macedonia","Benin","Nigeria","Burkina Faso","Uganda","Papua New Guinea","Ecuador","Armenia","Mexico","Tanzania","Malta","Serbia","Niger","South Korea","Latvia","Algeria","New Zealand","Paraguay","Djibouti","Australia","Netherlands","Czech Republic","Sierra Leone","Iraq","Cameroon","Nepal","Guinea","Chile","Qatar","Mauritania","Honduras","Nicaragua","Ireland","Indonesia","Madagascar","Lithuania","Moldova","Switzerland","Iran","Oman","Equatorial Guinea","Georgia","Ivory Coast","Uzbekistan","Chad","Sweden","Mongolia","Vietnam","Peru","Bangladesh","United Arab Emirates","Ethiopia","Denmark","Palestine","Syria","Tajikistan","Comoros","Taiwan","Guatemala","Cambodia","Luxembourg","Saudi Arabia","Kyrgyzstan","Botswana","Turkey","Guyana","Bulgaria","Belarus","Kazakhstan","Estonia","Azerbaijan","Swaziland","Congo","Kosovo","Bosnia and Herzegovina","Haiti","Burundi","Hong Kong","Afghanistan","Cayman Islands","Turkmenistan","Kuwait","Brunei","Puerto Rico","Macau","Mali","Somalia","South Sudan","Monaco","New Caledonia","Liechtenstein","East Timor"],"legendgroup":"Other","marker":{"color":"lightgray","size":[30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30],"sizemode":"area","sizeref":0.5,"symbol":"circle"},"mode":"markers","name":"Other","orientation":"v","showlegend":true,"x":[28.3,0.5,1.32,59.06,20.0,null,2.15,2.15,5.0,4.25,2.25,2.15,2.5,2.5,6.38,2.15,10.0,2.15,7.75,4.0,4.5,4.1,2.15,6.25,15.5,26.0,2.15,10.0,35.0,29.0,3.0,22.0,2.15,4.5,2.15,4.0,5.25,11.0,7.5,0.25,10.25,3.75,6.5,4.5,17.0,27.0,21.5,2.75,8.75,2.25,14.5,4.5,5.25,9.0,5.75,6.75,2.15,9.5,6.75,2.15,1.5,2.15,7.0,9.25,9.0,5.48,1.75,4.5,5.0,null,7.0,7.5,2.15,3.5,19.0,2.15,5.75,2.14,5.25,4.75,4.0,17.25,6.5,2.5,5.35,5.25,27.0,5.25,9.75,5.0,8.0,6.75,7.5,5.75,2.15,5.75,5.25,2.5,2.15,2.75,3.0,6.0,11.2,3.6,2.1 ...

# %%
import plotly.express as px

bar_df = by_cat.head(10).reset_index()
fig = px.bar(bar_df, x=category_col, y=numeric_col, title=f'Top 10 {category_col} (interactive)')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3791777900.py in <cell line: 0>()
#       1 import plotly.express as px
#       2
# ----> 3 bar_df = by_cat.head(10).reset_index()
#       4 fig = px.bar(bar_df, x=category_col, y=numeric_col, title=f'Top 10 {category_col} (interactive)')
#       5 fig.show()
#
# NameError: name 'by_cat' is not defined

# %% [markdown]
# ## Part 6 — Reflection
# - What needed adjusting when you switched datasets?
# - What was easier/harder vs the workbook?
# - What context/limitations should a policymaker know?

# %% [markdown]
# ## Part 7 — ⚡ Lightning Chart Demos — Teach-Out Instructions

# %% [markdown]
# ### What is a Lightning Demo?
# A **rapid-fire mini-presentation**: 2 minutes per group. Show **one chart** + **one insight**, not your whole notebook.
#
# ### Demo Format (2 minutes)
# 1. **Context (15 sec):** Dataset name + 1-sentence purpose.
# 2. **Chart + Insight (75–90 sec):** Show interactive Plotly chart; state one clear finding; name one wrangling step.
# 3. **Caveat or Next Step (15–30 sec):** One limitation OR next idea.
# 4. **Pass the mic (10 sec):** End with *“Any questions about our chart?”*
#
# ### Unique Angles
# - Aggregation choice (sum vs mean, raw vs normalized).
# - Data cleaning step (conversion, deduping).
# - Encoding (bar vs line vs scatter).
# - Interactivity (facet, hover, filter).
# - Comparability (per capita vs raw counts).
# - Temporal nuance (trend vs snapshot).
#
# 👉 If another group showed your angle, pick a different one.
#
# ### Flow for the Day
# - Groups present **clustered by chart type** (bars, lines, scatter, other).
# - Instructor summarizes similarities/differences after each cluster.
# - 15 groups × 2 min = ~30 minutes + transitions = ~40 minutes.
#
# ### Presenter Checklist
# - [ ] Dataset URL loads in Colab
# - [ ] Columns chosen make sense
# - [ ] One **interactive Plotly figure** with title + labels
# - [ ] Insight stated in one sentence
# - [ ] One cleaning step mentioned
#
# ### Audience Task
# After each cluster, jot 1 sentence:
# - What was **similar** across charts?
# - What was **different** (aggregation, encoding, interactivity)?
# - Which chart best supported a **policy decision**—and why?
#
# ---
# ### Quick Rubric (3 pts)
# - **Clarity of claim (1 pt)**
# - **Method fit (1 pt)**
# - **Insight/caveat (1 pt)**
# (Bonus +0.5 for meaningful interactivity)
#
# ---
# ### Minimal Code Patterns
#
# **Top-N bar:**
# ```python
# bar_df = df.groupby(category_col)[numeric_col].sum().nlargest(10).reset_index()
# fig = px.bar(bar_df, x=category_col, y=numeric_col,
#              title=f"Top 10 {category_col} by {numeric_col}")
# fig.show()
# ```
#
# **Time series:**
# ```python
# ts = (df.groupby(time_col)[numeric_col]
#         .sum()
#         .reset_index()
#         .sort_values(time_col))
# fig = px.line(ts, x=time_col, y=numeric_col, markers=True,
#               title=f"{numeric_col} over time")
# fig.show()
# ```
#
# **Scatter:**
# ```python
# fig = px.scatter(df, x=x_col, y=y_col, trendline="ols",
#                  title=f"{y_col} vs {x_col}")
# fig.show()
# ```
#
# ---
